# %% [markdown]
# #### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a lightweight web framework written in Python that enables developers to build web applications quickly and easily. It is known for its simplicity, flexibility, and extensibility.

# %% [markdown]
# Some advantages of Flask include:

# %% [markdown]
# 1. Simplicity: Flask has a simple and intuitive API, making it easy to learn and use.
#
# 2. Flexibility: It allows developers to make choices based on their project's requirements and offers the freedom to add or remove components as needed.
#
# 3. Extensibility: Flask has a rich ecosystem of extensions, enabling developers to enhance their applications with additional functionality.
#
# 4. Integrated development server: Flask includes a built-in development server, which facilitates quick testing and debugging during the development process.
#
# 5. Templating engine: Flask uses Jinja2 as its default templating engine, enabling the separation of presentation and business logic.
#
# 6. Python ecosystem: Being built with Python, Flask leverages the vast Python ecosystem, making it easy to integrate with other Python libraries and modules.

# %% [markdown]
# #### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello_world():
    return 'Hello World!!'

if __name__ == '__main__':
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Jul/2023 23:44:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jul/2023 23:44:07] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# ![flask.JPG](attachment:flask.JPG)

# %% [markdown]
# #### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# In Flask, app routing refers to the process of mapping URLs to specific functions in your web application. It allows you to define different routes (URL patterns) and associate them with corresponding view functions that handle the logic for processing requests and generating responses.

# %% [markdown]
# The @app.route() decorator is used in Flask to define routes. It binds a URL pattern to a specific view function that should be executed when a request matches that URL. The route decorator takes the URL pattern as a parameter and can be placed above a function definition.

# %% [markdown]
# .

# %% [markdown]
# #### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”  route to show the following details:
# #### Company Name: ABC Corporation
# #### Location: India
# #### Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def company_details():
    return '''Company Name: ABC Corporation
              Location: India
              Contact Detail: 999-999-9999'''

if __name__ == '__main__':
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Jul/2023 00:00:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jul/2023 00:01:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jul/2023 00:02:06] "GET /welcome HTTP/1.1" 200 -

# %% [markdown]
# ![flask-3.JPG](attachment:flask-3.JPG)

# %% [markdown]
# ![flask-2.JPG](attachment:flask-2.JPG)

# %% [markdown]
# .

# %% [markdown]
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# In Flask, the url_for() function is used for URL building. It generates a URL for a given endpoint, taking into account the routing rules defined in your Flask application. It is useful when you want to dynamically generate URLs for specific routes, especially when the routes have variable parts.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route("/")
def home():
    return "This is the home page"

@app.route(""/contact")
def contact():
    return "This is the contact page"

if __name__ == "__main__":
    with app.test_request_context():
        print(url_for("home"))
        print(url_for("contact"))
